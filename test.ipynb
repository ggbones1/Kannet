# %%
import pandas as pd
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import r2_score, mean_squared_error
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch
from kan import *

# create a KAN: 2D inputs, 1D output, and 5 hidden neurons. cubic spline (k=3), 5 grid intervals (grid=5).
model = KAN(width=[4,5,2], grid=5, k=3, seed=0)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# 读取xlsx文件
file_path = 'D:\OneDrive - Officials\OneDrive - Mraz Cindy\done\毕设资料\计算公式说明\数据库.xlsx'  # 替换为你的xlsx文件路径
df = pd.read_excel(file_path, engine='openpyxl')

# 打乱行顺序并按8:2的比例分成训练集和测试集
train_df, test_df = train_test_split(df, test_size=0.2, random_state=42)

# 输出结果
print("训练集样本数:", len(train_df))
print("测试集样本数:", len(test_df))
# Out:
# 训练集样本数: 307
# 测试集样本数: 77

# %%
# 提取第2，3，4，5列的数据
input = train_df.iloc[:, 1:5]
output = train_df.iloc[:, 5:7]
test_input = test_df.iloc[:, 1:5]
test_label = test_df.iloc[:, 5:7]
# 将DataFrame转换为numpy数组并调整其维度为4
array1 = input.to_numpy()
array2 = output.to_numpy()
array3 = test_input.to_numpy()
array4 = test_label.to_numpy()
input=torch.tensor(array1, dtype=torch.float32)
ouput=torch.tensor(array2, dtype=torch.float32)
test_input=torch.tensor(array3, dtype=torch.float32)
test_label=torch.tensor(array4, dtype=torch.float32)

# %%
import torch

def normalize_columns(tensor):
    # 确保输入是2D张量
    assert tensor.dim() == 2, "Input tensor must be 2D"
    
    # 获取最小值和最大值
    col_min = tensor.min(dim=0, keepdim=True).values
    col_max = tensor.max(dim=0, keepdim=True).values
    
    # 防止除以零的情况
    denom = col_max - col_min
    denom[denom == 0] = 1  # 如果列中所有值相等，避免除以零
    
    # 进行归一化
    normalized_tensor = (tensor - col_min) / denom
    return normalized_tensor
# 对每一列进行归一化
input= normalize_columns(input)
ouput= normalize_columns(ouput)
test_input= normalize_columns(test_input)
test_label= normalize_columns(test_label)
dataset={'train_input':input,'test_input':test_input,'train_label':ouput,'test_label':test_label}

# %%
model(input)
model.plot(beta=100)

# %% [markdown]
# ### model.train函数介绍
# 这个函数的文档解释了`training`函数的各个参数。以下是对每个参数的详细解释：
#
# 1. `dataset` : `dict`
#     - 包含训练和测试数据集，字典结构如下：
#         - `dataset['train_input']`: 训练输入数据
#         - `dataset['train_label']`: 训练标签数据
#         - `dataset['test_input']`: 测试输入数据
#         - `dataset['test_label']`: 测试标签数据
#
# 2. `opt` : `str`
#     - 优化器类型，值可以是 "LBFGS" 或 "Adam"，决定了使用的优化算法。
#
# 3. `steps` : `int`
#     - 训练步骤数，表示训练过程中的总步数。
#
# 4. `log` : `int`
#     - 日志记录频率，表示每隔多少步记录一次日志信息。
#
# 5. `lamb` : `float`
#     - 总体惩罚强度系数，用于正则化项的总体惩罚。
#
# 6. `lamb_l1` : `float`
#     - L1惩罚强度系数，用于稀疏化正则化。
#
# 7. `lamb_entropy` : `float`
#     - 熵惩罚强度系数，用于熵正则化。
#
# 8. `lamb_coef` : `float`
#     - 系数大小惩罚强度系数，用于控制系数大小的正则化。
#
# 9. `lamb_coefdiff` : `float`
#     - 相邻系数差异（平滑性）惩罚强度系数，用于控制相邻系数差异的正则化。
#
# 10. `update_grid` : `bool`
#     - 是否定期更新网格。如果为 `True`，则在特定步骤前定期更新网格。
#
# 11. `grid_update_num` : `int`
#     - 在停止网格更新步骤之前，网格更新的次数。
#
# 12. `stop_grid_update_step` : `int`
#     - 在此步骤之后不再更新网格。
#
# 13. `batch` : `int`
#     - 批量大小。如果值为 -1，则使用整个数据集进行训练（即全量批次）。
#
# 14. `small_mag_threshold` : `float`
#     - 确定大小数的阈值（可能对小数施加较大的惩罚）。
#
# 15. `small_reg_factor` : `float`
#     - 对小因子相对于大因子的惩罚强度。
#
# 16. `device` : `str`
#     - 计算设备，例如 "cpu" 或 "cuda"（用于指定运行训练的硬件设备）。
#
# 17. `save_fig_freq` : `int`
#     - 每隔多少步保存一次图像。
#
# 这些参数共同定义了训练过程中的数据、优化策略、正则化方法、批量处理方式以及日志记录和图像保存的频率。

# %%
# train the model
model.train(dataset, opt="Adam", steps=100, lamb=0.01, lamb_entropy=10.);

model.plot(beta=100)
# Out:
# train loss: 1.88e-01 | test loss: 2.07e-01 | reg: 1.10e+02 : 100%|█| 100/100 [00:03<00:00, 27.04it/s

# %%
model.prune()
model.plot(mask=True)

# %%
model = model.prune()
model(dataset['train_input'])
model.plot()

# %%
model.train(dataset, opt="LBFGS", steps=50)
# Out:
# train loss: 1.10e-01 | test loss: 1.41e-01 | reg: 9.55e+00 : 100%|██| 50/50 [00:06<00:00,  7.38it/s]
# {'train_loss': [array(0.11856781, dtype=float32),
#   array(0.11348084, dtype=float32),
#   array(0.11190709, dtype=float32),
#   array(0.11138176, dtype=float32),
#   array(0.11126372, dtype=float32),
#   array(0.11281102, dtype=float32),
#   array(0.11217587, dtype=float32),
#   array(0.11178476, dtype=float32),
#   array(0.11159696, dtype=float32),
#   array(0.11142674, dtype=float32),
#   array(0.11146045, dtype=float32),
#   array(0.11141813, dtype=float32),
#   array(0.11128459, dtype=float32),
#   array(0.11118387, dtype=float32),
#   array(0.111102, dtype=float32),
#   array(0.11112844, dtype=float32),
#   array(0.11103378, dtype=float32),
#   array(0.11092631, dtype=float32),
#   array(0.11090929, dtype=float32),
#   array(0.11088706, dtype=float32),
#   array(0.1108722, dtype=float32),
#   array(0.11086656, dtype=float32),
#   array(0.11085767, dtype=float32),
#   array(0.11084693, dtype=float32),
#   array(0.11083538, dtype=float32),
#   array(0.11086994, dtype=float32),
#   array(0.11086553, dtype=float32),
#   array(0.11086255, dtype=float32),
#   array(0.11085498, dtype=float32),
#   array(0.11085499, dtype=float32),
#   array(0.11083228, dtype=float32),
#   array(0.11080875, dtype=float32),
#   array(0.11078282, dtype=float32),
#   array(0.11069844, dtype=float32),
#   array(0.11055865, dtype=float32),
#   array(0.11047231, dtype=float32),
#   array(0.11038478, dtype=float32),
#   array(0.11034677, dtype=float32),
#   array(0.11029372, dtype=float32),
#   array(0.11022893, dtype=float32),
#   array(0.11017715, dtype=float32),
#   array(0.11014415, dtype=float32),
#   array(0.11011574, dtype=float32),
#   array(0.11006856, dtype=float32),
#   array(0.11001688, dtype=float32),
#   array(0.10987934, dtype=float32),
#   array(0.10982857, dtype=float32),
#   array(0.109742, dtype=float32),
#   array(0.10961958, dtype=float32),
#   array(0.10957324, dtype=float32)],
#  'test_loss': [array(0.14680502, dtype=float32),
#   array(0.14782164, dtype=float32),
#   array(0.14578328, dtype=float32),
#   array(0.14655426, dtype=float32),
#   array(0.14629194, dtype=float32),
#   array(0.14769961, dtype=float32),
#   array(0.14802834, dtype=float32),
#   array(0.14802282, dtype=float32),
#   array(0.14789046, dtype=float32),
#   array(0.14754651, dtype=float32),
#   array(0.14811574, dtype=float32),
#   array(0.14779197, dtype=float32),
#   array(0.14740485, dtype=float32),
#   array(0.14772622, dtype=float32),
#   array(0.14752203, dtype=float32),
#   array(0.14792119, dtype=float32),
#   array(0.14778705, dtype=float32),
#   array(0.14819187, dtype=float32),
#   array(0.14803375, dtype=float32),
#   array(0.1480504, dtype=float32),
#   array(0.1480928, dtype=float32),
#   array(0.14804402, dtype=float32),
#   array(0.1478909, dtype=float32),
#   array(0.14758955, dtype=float32),
#   array(0.14741236, dtype=float32),
#   array(0.1471949, dtype=float32),
#   array(0.14725396, dtype=float32),
#   array(0.14725547, dtype=float32),
#   array(0.14722545, dtype=float32),
#   array(0.14722547, dtype=float32),
#   array(0.14696038, dtype=float32),
#   array(0.14703481, dtype=float32),
#   array(0.14713465, dtype=float32),
#   array(0.1470148, dtype=float32),
#   array(0.14620847, dtype=float32),
#   array(0.14552897, dtype=float32),
#   array(0.14533643, dtype=float32),
#   array(0.14488903, dtype=float32),
#   array(0.14494105, dtype=float32),
#   array(0.1450091, dtype=float32),
#   array(0.14471085, dtype=float32),
#   array(0.14429559, dtype=float32),
#   array(0.14395641, dtype=float32),
#   array(0.14377299, dtype=float32),
#   array(0.14331196, dtype=float32),
#   array(0.14302668, dtype=float32),
#   array(0.14271872, dtype=float32),
#   array(0.14172697, dtype=float32),
#   array(0.14153427, dtype=float32),
#   array(0.14137521, dtype=float32)],
#  'reg': [array(10.619088, dtype=float32),
#   array(10.307425, dtype=float32),
#   array(10.417759, dtype=float32),
#   array(10.365191, dtype=float32),
#   array(10.34353, dtype=float32),
#   array(7.331752, dtype=float32),
#   array(7.1833878, dtype=float32),
#   array(7.335747, dtype=float32),
#   array(7.3756223, dtype=float32),
#   array(7.569577, dtype=float32),
#   array(7.9852047, dtype=float32),
#   array(8.184902, dtype=float32),
#   array(8.704633, dtype=float32),
#   array(8.8542595, dtype=float32),
#   array(9.206853, dtype=float32),
#   array(8.134329, dtype=float32),
#   array(8.804869, dtype=float32),
#   array(9.277653, dtype=float32),
#   array(9.230896, dtype=float32),
#   array(9.35449, dtype=float32),
#   array(7.776229, dtype=float32),
#   array(7.880848, dtype=float32),
#   array(7.9800587, dtype=float32),
#   array(8.018265, dtype=float32),
#   array(8.10002, dtype=float32),
#   array(7.841795, dtype=float32),
#   array(7.846074, dtype=float32),
#   array(7.8373494, dtype=float32),
#   array(7.8280377, dtype=float32),
#   array(7.8280373, dtype=float32),
#   array(7.873809, dtype=float32),
#   array(7.9125543, dtype=float32),
#   array(7.9664664, dtype=float32),
#   array(7.821451, dtype=float32),
#   array(7.974228, dtype=float32),
#   array(8.017267, dtype=float32),
#   array(7.887452, dtype=float32),
#   array(7.851665, dtype=float32),
#   array(8.04756, dtype=float32),
#   array(8.137594, dtype=float32),
#   array(8.027519, dtype=float32),
#   array(8.102777, dtype=float32),
#   array(8.228889, dtype=float32),
#   array(8.42835, dtype=float32),
#   array(8.702999, dtype=float32),
#   array(8.743244, dtype=float32),
#   array(8.943693, dtype=float32),
#   array(9.426583, dtype=float32),
#   array(9.443898, dtype=float32),
#   array(9.548021, dtype=float32)]}

# %%
mode = "auto" # "manual"

if mode == "manual":
    # manual mode
    model.fix_symbolic(0,0,0,'sin');
    model.fix_symbolic(0,1,0,'x^2');
    model.fix_symbolic(1,0,0,'exp');
elif mode == "auto":
    # automatic mode
    lib = ['x','x^2','x^3','x^4','exp','log','sqrt','tanh','sin','abs']
    model.auto_symbolic(lib=lib)
# Out:
# fixing (0,0,0) with tanh, r2=0.9996846318244934
# fixing (0,1,0) with exp, r2=1.0000004768371582
# fixing (0,2,0) with abs, r2=0.0
# fixing (0,3,0) with exp, r2=0.9930374622344971
# fixing (1,0,0) with sin, r2=0.7972995638847351
# fixing (1,0,1) with sin, r2=0.9876116514205933

# %%
model.auto_symbolic(lib=['exp','sin','x^2','x^4',])
model.train(dataset, opt='LBFGS', steps=50, lamb=0.0, update_grid=False)
model.symbolic_formula()
# Out:
# skipping (0,0,0) since already symbolic
# skipping (0,1,0) since already symbolic
# skipping (0,2,0) since already symbolic
# skipping (0,3,0) since already symbolic
# skipping (1,0,0) since already symbolic
# skipping (1,0,1) since already symbolic
# train loss: 2.17e-01 | test loss: 2.13e-01 | reg: 9.60e+00 : 100%|██| 50/50 [00:00<00:00, 56.48it/s]
# ([-5.63*sin(3.18*tanh(10.0*x_1 - 7.6) - 9.73 + 0.07*exp(-0.64*x_4) - 0.07*exp(-4.88*x_2)) - 1.24,
#   0.91*sin(5.05*tanh(10.0*x_1 - 7.6) - 23.23 + 0.12*exp(-0.64*x_4) - 0.11*exp(-4.88*x_2)) + 0.24],
#  [x_1, x_2, x_3, x_4])

# %%
model.plot()

# %%
model.auto_symbolic(lib=['exp','sin','x^2','x^3','x^4','log','sqrt','tanh','abs','x'])
model.train(dataset, opt='LBFGS', steps=50, lamb=0.00, update_grid=False)
model.symbolic_formula()
# Out:
# skipping (0,0,0) since already symbolic
# skipping (0,1,0) since already symbolic
# skipping (0,2,0) since already symbolic
# skipping (0,3,0) since already symbolic
# skipping (1,0,0) since already symbolic
# skipping (1,0,1) since already symbolic
# train loss: 2.17e-01 | test loss: 2.13e-01 | reg: 9.60e+00 : 100%|██| 50/50 [00:01<00:00, 25.43it/s]
# ([-5.63*sin(3.18*tanh(10.0*x_1 - 7.6) - 9.73 + 0.07*exp(-0.64*x_4) - 0.07*exp(-4.88*x_2)) - 1.24,
#   0.91*sin(5.05*tanh(10.0*x_1 - 7.6) - 23.23 + 0.12*exp(-0.64*x_4) - 0.11*exp(-4.88*x_2)) + 0.24],
#  [x_1, x_2, x_3, x_4])

# %%
model.symbolic_formula(floating_digit=4)
# Out:
# ([-5.6313*sin(3.1843*tanh(10.0*x_1 - 7.6) - 9.7315 + 0.0748*exp(-0.6358*x_4) - 0.0683*exp(-4.876*x_2)) - 1.2353,
#   0.9054*sin(5.0479*tanh(10.0*x_1 - 7.6) - 23.2256 + 0.1186*exp(-0.6358*x_4) - 0.1082*exp(-4.876*x_2)) + 0.2435],
#  [x_1, x_2, x_3, x_4])
